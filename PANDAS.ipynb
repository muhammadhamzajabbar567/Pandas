# %%
import pandas as pd

My_Dataset = {
    "Names": ["Abdullah Bin Abu Kahafa","Umar Bin Khatab", "Usman Bin Affan","Ali Bin Talib"],
    "Caliph": [1,2,3,4]
}

new_Dataset = pd.DataFrame(My_Dataset)
print(new_Dataset)
# Out:
#                      Names  Caliph
# 0  Abdullah Bin Abu Kahafa       1
# 1          Umar Bin Khatab       2
# 2          Usman Bin Affan       3
# 3            Ali Bin Talib       4

# %%
import pandas as pd
print(pd.__version__)

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.4.4

# %%
import pandas as pd

a = [1,3,5,8,9]
y = pd.Series(a)
print(y)
# Out:
# 0    1
# 1    3
# 2    5
# 3    8
# 4    9
# dtype: int64

# %%
import pandas as pd

a = [1,3,4,9,3,74,9,1,8,6,4,9,2]
b = pd.Series(a, index=["a",'b','c','d','e','f','g','h','i','j','k','l','m'])
print(b)
# Out:
# a     1
# b     3
# c     4
# d     9
# e     3
# f    74
# g     9
# h     1
# i     8
# j     6
# k     4
# l     9
# m     2
# dtype: int64

# %%
import pandas as pd 
Data= {
    "RANKS":["First"," Second "," Third"],
    "NAMES":["ABC",'DEF','GHI'],
    "BRANCHES":["IT","IT","IT"]
}
print(pd.DataFrame(Data))
# Out:
#   RANKS          NAMES    DEPARTMENT
# 0  First    ABC  IT
# 1  Second  DEF  IT
# 2  Third   GHI  IT

# %%
import pandas as pd 
Data= {
    "RANKS":["S/LT","S/LT","S/LT"],
    "NAMES":["NABEEL AHMED",'MUHAMMAD UMER','QAISER HABIB'],
    "BRANCHES":["Operations","Operations","Operations"]
}
Result = pd.DataFrame(Data)
print(Result.loc[0:2])
# Out:
#   RANKS          NAMES    BRANCHES
# 0  S/LT   NABEEL AHMED  Operations
# 1  S/LT  MUHAMMAD UMER  Operations
# 2  S/LT   QAISER HABIB  Operations

# %%
import pandas as pd
pd.options.display.max_rows = 50
df = pd.read_csv('data.csv')
print(df.to_string())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import pandas as pd

df = pd.read_csv('Case.csv')
print(df.fillna(130,inplace=True))
# Out:
#       case_id           province             city  group                                 infection_case  confirmed    latitude    longitude
# 0     1000001              Seoul       Yongsan-gu   True                                  Itaewon Clubs        139   37.538621   126.992652
# 1     1000002              Seoul        Gwanak-gu   True                                        Richway        119    37.48208   126.901384
# 2     1000003              Seoul          Guro-gu   True                            Guro-gu Call Center         95   37.508163   126.884387
# 3     1000004              Seoul     Yangcheon-gu   True                    Yangcheon Table Tennis Club         43   37.546061   126.874209
# 4     1000005              Seoul        Dobong-gu   True                                Day Care Center         43   37.679422   127.044374
# 5     1000006              Seoul          Guro-gu   True                          Manmin Central Church         41   37.481059   126.894343
# ...

# %%
import pandas as pd 

df = pd.read_csv('Case.csv')
n_df = df.dropna()
print(n_df.to_string())
# Out:
#       case_id           province             city  group                                 infection_case  confirmed    latitude    longitude
# 0     1000001              Seoul       Yongsan-gu   True                                  Itaewon Clubs        139   37.538621   126.992652
# 1     1000002              Seoul        Gwanak-gu   True                                        Richway        119    37.48208   126.901384
# 2     1000003              Seoul          Guro-gu   True                            Guro-gu Call Center         95   37.508163   126.884387
# 3     1000004              Seoul     Yangcheon-gu   True                    Yangcheon Table Tennis Club         43   37.546061   126.874209
# 4     1000005              Seoul        Dobong-gu   True                                Day Care Center         43   37.679422   127.044374
# 5     1000006              Seoul          Guro-gu   True                          Manmin Central Church         41   37.481059   126.894343
# ...

# %%
import pandas as pd 

df = pd.read_csv('Case.csv')
n_df = df['province'].fillna(1358,inplace = True)
print(n_df)
# Out:
# None

# %%
import pandas as pd

df = pd.read_csv('Case.csv')
df.corr()
# Out:
#             case_id     group  confirmed
#  case_id   1.000000 -0.131021  -0.069052
# group     -0.131021  1.000000  -0.009669
# confirmed -0.069052 -0.009669   1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Case.csv')

df.plot()

plt.show()
# Out:
# C:\Users\Hamza\AppData\Local\Temp\ipykernel_9816\1843053129.py:8: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
import scipy

print(scipy.__version__)
# Out:
# 1.9.1
